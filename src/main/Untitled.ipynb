# %%
import os
def dir_walk(test):

    Tree = {}
    
    for root, dirs, files in os.walk(test, topdown=True):
        # print(root, dirs, files)
        if root not in Tree.keys():
            Tree[root] = []

        for name in dirs:
            Tree[root].append({'type':'dir','value':os.path.join(root,name)})
        
        for name in files:
            Tree[root].append({'type' : 'file', 'value': os.path.join(root ,name)})
        
        # print(Tree)
    
    return Tree

# %%
dir_walk('test')
# Out:
# {'test': [{'type': 'dir', 'value': 'test\\tensor2tensor'},
#   {'type': 'file', 'value': 'test\\class.py'},
#   {'type': 'file', 'value': 'test\\tags.txt'},
#   {'type': 'file', 'value': 'test\\test.dat'}],
#  'test\\tensor2tensor': [{'type': 'dir', 'value': 'test\\tensor2tensor\\.git'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\docs'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\oss_scripts'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.gitignore'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.travis.yml'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\AUTHORS'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\CONTRIBUTING.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\floyd.yml'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\floyd_requirements.txt'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\ISSUE_TEMPLATE.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\LICENSE'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\pylintrc'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\README.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\setup.py'}],
#  'test\\tensor2tensor\\.git': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\hooks'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\info'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\logs'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\refs'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\COMMIT_EDITMSG'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\config'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\description'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\HEAD'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\index'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\ORIG_HEAD'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\packed-refs'}],
#  'test\\tensor2tensor\\.git\\hooks': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\applypatch-msg.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\commit-msg.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\fsmonitor-watchman.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\post-update.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-applypatch.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-commit.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-merge-commit.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-push.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-rebase.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\pre-receive.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\prepare-commit-msg.sample'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\hooks\\update.sample'}],
#  'test\\tensor2tensor\\.git\\info': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\info\\exclude'}],
#  'test\\tensor2tensor\\.git\\logs': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\logs\\refs'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\logs\\HEAD'}],
#  'test\\tensor2tensor\\.git\\logs\\refs': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\logs\\refs\\heads'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\logs\\refs\\remotes'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\logs\\refs\\stash'}],
#  'test\\tensor2tensor\\.git\\logs\\refs\\heads': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\logs\\refs\\heads\\master'}],
#  'test\\tensor2tensor\\.git\\logs\\refs\\remotes': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\logs\\refs\\remotes\\origin'}],
#  'test\\tensor2tensor\\.git\\logs\\refs\\remotes\\origin': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\logs\\refs\\remotes\\origin\\HEAD'}],
#  'test\\tensor2tensor\\.git\\objects': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\objects\\37'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\3f'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\45'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\52'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\6d'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\93'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\ae'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\d5'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\d9'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\e1'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\e3'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\f0'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\ff'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\info'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\objects\\pack'}],
#  'test\\tensor2tensor\\.git\\objects\\37': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\37\\b1fd6d8ca74b4d9b9b15ae64a91705c735d595'}],
#  'test\\tensor2tensor\\.git\\objects\\3f': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\3f\\4a4df9f6bdd4a302605eaac096c9e34e228627'}],
#  'test\\tensor2tensor\\.git\\objects\\45': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\45\\17944f2ff57fc7334fef6df5b9b9e769cc995e'}],
#  'test\\tensor2tensor\\.git\\objects\\52': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\52\\d1833f49f953c5cde6b7cb7795228318e67781'}],
#  'test\\tensor2tensor\\.git\\objects\\6d': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\6d\\213bb21ce786354f5a72be72e21406ecc3276b'}],
#  'test\\tensor2tensor\\.git\\objects\\93': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\93\\20609cc0154d0fdac2cc865de4bd471dc8ec79'}],
#  'test\\tensor2tensor\\.git\\objects\\ae': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\ae\\bc7eb28c442438856ccabf2195c0cac3fe908f'}],
#  'test\\tensor2tensor\\.git\\objects\\d5': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\d5\\7ebbe0a12fe49fb574ca3d727e837973c0992d'}],
#  'test\\tensor2tensor\\.git\\objects\\d9': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\d9\\44ff860704b55522a9de36e725e4087ff06560'}],
#  'test\\tensor2tensor\\.git\\objects\\e1': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\e1\\338700eca032d48da5b375571c1e7e0dfd7897'}],
#  'test\\tensor2tensor\\.git\\objects\\e3': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\e3\\26f112c993b0a4d37843ec92b8ade3ebcafbd6'}],
#  'test\\tensor2tensor\\.git\\objects\\f0': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\f0\\e3cb75609cd61b73b6c7fc626e12cbd2658040'}],
#  'test\\tensor2tensor\\.git\\objects\\ff': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\ff\\36275bbf467bf38d93382725c7f8011787da9a'}],
#  'test\\tensor2tensor\\.git\\objects\\info': [],
#  'test\\tensor2tensor\\.git\\objects\\pack': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\pack\\pack-95d2ebca47ab2699d2c0041b728579083ca9afef.idx'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\objects\\pack\\pack-95d2ebca47ab2699d2c0041b728579083ca9afef.pack'}],
#  'test\\tensor2tensor\\.git\\refs': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\refs\\heads'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\refs\\remotes'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\.git\\refs\\tags'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\.git\\refs\\stash'}],
#  'test\\tensor2tensor\\.git\\refs\\heads': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\refs\\heads\\master'}],
#  'test\\tensor2tensor\\.git\\refs\\remotes': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\.git\\refs\\remotes\\origin'}],
#  'test\\tensor2tensor\\.git\\refs\\remotes\\origin': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\.git\\refs\\remotes\\origin\\HEAD'}],
#  'test\\tensor2tensor\\.git\\refs\\tags': [],
#  'test\\tensor2tensor\\docs': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\docs\\tutorials'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\cloud_mlengine.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\cloud_tpu.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\docs\\distributed_training.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\index.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\multi_problem.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\new_model.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\new_problem.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\overview.md'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\docs\\walkthrough.md'}],
#  'test\\tensor2tensor\\docs\\tutorials': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\docs\\tutorials\\asr_with_transformer.md'}],
#  'test\\tensor2tensor\\oss_scripts': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\oss_scripts\\oss_integration_test.sh'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\oss_scripts\\oss_pip_install.sh'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\oss_scripts\\oss_release.sh'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\oss_scripts\\oss_tests.sh'}],
#  'test\\tensor2tensor\\tensor2tensor': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\envs'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\insights'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\layers'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\metrics'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\models'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\rl'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\serving'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\test_data'},
#   {'type': 'dir', 'value': 'test\\tensor2tensor\\tensor2tensor\\utils'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\tensor2tensor\\problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\problems_colab.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\problems_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\bin': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\build_vocab.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\make_tf_configs.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-avg-all'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-bleu'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-datagen'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-decoder'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-eval'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-exporter'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-insights-server'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-make-tf-configs'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-query-server'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-trainer'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t-translate-all'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_attack.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_avg_all.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_bleu.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_datagen.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_decoder.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_distill.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_eval.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_prune.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_trainer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_trainer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\t2t_translate_all.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\bin\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikifact'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic_math.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic_math_deepmind.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic_math_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic_math_two_variables.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\algorithmic_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\allen_brain.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\allen_brain_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\all_problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\audio.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\audio_encoder.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\audio_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\babi_qa.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\bair_robot_pushing.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\celeba.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\celebahq.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\celeba_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\cifar.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\cipher.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\cleaner_en_xx.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\cnn_dailymail.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\cola.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\common_voice.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\common_voice_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\conll_ner.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\desc2code.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\desc2code_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dialog_abstract.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dialog_cornell.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dialog_dailydialog.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dialog_opensubtitles.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dialog_personachat.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dna_encoder.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\dna_encoder_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\enwik8.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\fsns.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\function_docstring.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\generator_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\generator_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\gene_expression.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\gene_expression_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\google_robot_pushing.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\gym_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\gym_env_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ice_parsing.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\imagenet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\imagenet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\image_lsun.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\image_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\image_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\imdb.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\inspect_tfrecord.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\lambada.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\librispeech.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\lm1b.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\lm1b_imdb.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\lm1b_mnli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\mnist.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\moving_mnist.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\mrpc.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\mscoco.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\mscoco_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\multinli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\multi_problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\multi_problem_v2.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\multi_problem_v2_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ocr.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\paraphrase_ms_coco.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\paraphrase_ms_coco_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\pointer_generator_word.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\problem_hparams.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\problem_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\program_search.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\program_search_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ptb.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\qnli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\quora_qpairs.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\rte.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\scitail.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\snli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\speech_recognition.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\squad.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\sst_binary.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\stanford_nli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\style_transfer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\style_transfer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\subject_verb_agreement.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\text_encoder.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\text_encoder_build_subword.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\text_encoder_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\text_problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\text_problems_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\timeseries.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\timeseries_data_generator.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\timeseries_data_generator_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\timeseries_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\tokenizer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\tokenizer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\transduction_problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\transduction_problems_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_encs.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_ende.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_ende_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enes.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enfr.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enid.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enmk.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enro.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_entn.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_envi.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_enzh.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\translate_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\video_generated.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\video_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\video_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\vqa.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\vqa_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wiki.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikitext103.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wiki_lm.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wiki_multi_problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wiki_revision.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wiki_revision_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wnli.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wsj_parsing.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\yelp_full.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\yelp_polarity.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\testdata'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\pack_sequences_ops.cc'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\pack_sequences_ops_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\subword_text_encoder.cc'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\subword_text_encoder.h'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\subword_text_encoder_ops.cc'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\subword_text_encoder_ops_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\subword_text_encoder_test.cc'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\testdata': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\ops\\testdata\\subwords'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data\\1.csv'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data\\corpus-1.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data\\corpus-2.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data\\vocab-1.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\test_data\\vocab-2.txt'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikifact': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikifact\\README.md'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\test_data'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\delete_instances.sh'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\generate_vocab.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\get_references_commoncrawl.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\get_references_web.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\get_references_web_single_group.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\html.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\parallel_launch.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\produce_examples.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\validate_data.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\wikisum.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\test_data': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\test_data\\para_bad1.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\data_generators\\wikisum\\test_data\\para_good1.txt'}],
#  'test\\tensor2tensor\\tensor2tensor\\envs': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\env_problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\env_problem_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\env_problem_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\gym_env_problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\gym_env_problem_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\gym_spaces_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\gym_spaces_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\mujoco_problems.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\mujoco_problems_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\rendered_env_problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\rendered_env_problem_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\tic_tac_toe_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\tic_tac_toe_env_problem.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\tic_tac_toe_env_problem_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\tic_tac_toe_env_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\time_step.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\time_step_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\trajectory.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\trajectory_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\envs\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\graph.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\insight_configuration.proto'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\query_processor.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\server.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\transformer_model.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\attention_visualization'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\explore_view'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\graph_visualization'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\insights_app'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\processing_visualization'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\query_card'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\translation_result'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\.bowerrc'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\bower.json'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\common-types.js'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\index.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\tensor2tensor.html'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\attention_visualization': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\attention_visualization\\attention-visualization.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\attention_visualization\\attention-visualization.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\explore_view': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\explore_view\\explore-view.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\explore_view\\explore-view.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\graph_visualization': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\graph_visualization\\graph-visualization.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\graph_visualization\\graph-visualization.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\insights_app': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\insights_app\\insights-app.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\insights_app\\insights-app.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector\\language-selector-content.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector\\language-selector-content.js'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector\\language-selector.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\language_selector\\language-selector.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\processing_visualization': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\processing_visualization\\processing-visualization.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\processing_visualization\\processing-visualization.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\query_card': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\query_card\\query-card.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\query_card\\query-card.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\translation_result': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\translation_result\\translation-result.html'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\insights\\polymer\\translation_result\\translation-result.js'}],
#  'test\\tensor2tensor\\tensor2tensor\\layers': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\area_attention.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\area_attention_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_attention.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_attention_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_audio.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_hparams.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_image_attention.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_image_attention_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_layers_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_video.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\common_video_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\discretization.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\discretization_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\latent_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\latent_layers_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\message_passing_attention.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\modalities.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\modalities_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\ngram.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\ngram_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_glow_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_glow_layers_ops.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_glow_layers_ops_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_glow_layers_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_memory.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\transformer_memory_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\vqa_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\vq_discrete.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\layers\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\metrics': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\metrics\\video_conditional_fvd.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\metrics\\video_conditional_fvd_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\metrics\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\models': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\basic.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\basic_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\bytenet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\bytenet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\distillation.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\evolved_transformer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\evolved_transformer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\image_transformer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\image_transformer_2d.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\image_transformer_2d_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\image_transformer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\lstm.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\lstm_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_image_transformer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_image_transformer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_resnet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_transformer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_transformer2.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\mtf_transformer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_assistant.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_gpu.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_gpu_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\resnet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\resnet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\revnet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\revnet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\shake_shake.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\slicenet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\slicenet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\text_cnn.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\transformer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\transformer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\vanilla_gan.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\xception.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\xception_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\nas_layers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\nas_layers_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\nas_model.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\nas_model_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\neural_architecture_search\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\models\\research': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\adafactor_experiments.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\aligned.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\attention_lm.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\attention_lm_moe.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\autoencoders.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\autoencoders_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\research\\cycle_gan.py'},
#   {'type': 'file',
# ...
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\basic_recurrent_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\basic_stochastic.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\basic_stochastic_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\emily.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\emily_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\epva.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\epva_params.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\next_frame_glow.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_conv3d_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_conv_lstm_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_conv_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_interpolate.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_test_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\nfg_uncond_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\savp.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\savp_params.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\savp_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\sv2p.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\sv2p_params.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\sv2p_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\tests_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\models\\video\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\notebooks': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks\\asr_transformer.ipynb'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks\\hello_t2t-rl.ipynb'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks\\hello_t2t.ipynb'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks\\t2t_problem.ipynb'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\notebooks\\Transformer_translate.ipynb'}],
#  'test\\tensor2tensor\\tensor2tensor\\rl': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\batch_dqn_agent_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\batch_runner_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\datagen_with_agent.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\dopamine_connector.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\evaluator.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\evaluator_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\gym_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\gym_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\player.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\player_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\policy_learner.py'},
#   {'type': 'file', 'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\ppo.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\ppo_learner.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\restarter.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\restarter_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\rl_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_agent_only.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_params.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_recurrent_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_stochastic_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_sv2p_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_based_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_free.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_free_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\trainer_model_free_tictactoe_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\rl\\envs': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\in_graph_batch_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\py_func_batch_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\simulated_batch_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\simulated_batch_gym_env.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\tf_atari_wrappers.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\rl\\envs\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\serving': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\serving\\export.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\serving\\query.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\serving\\README.md'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\serving\\serving_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\serving\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\test_data': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\example_usr_dir'},
#   {'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\vocab.translate_ende_wmt32k.32768.subwords'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\vocab.translate_ende_wmt8k.8192.subwords'}],
#  'test\\tensor2tensor\\tensor2tensor\\test_data\\example_usr_dir': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\example_usr_dir\\my_submodule.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\example_usr_dir\\requirements.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\example_usr_dir\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\checkpoint'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\flags.txt'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\hparams.json'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\model.ckpt-1.data-00000-of-00002'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\model.ckpt-1.data-00001-of-00002'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\model.ckpt-1.index'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\test_data\\transformer_test_ckpt\\model.ckpt-1.meta'}],
#  'test\\tensor2tensor\\tensor2tensor\\utils': [{'type': 'dir',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\adafactor.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\adv_attack_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\avg_checkpoints.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\beam_search.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\beam_search_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\bleu_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\bleu_hook_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\checkpoint_compatibility_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\cloud_mlengine.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\compute_video_metrics.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\contrib.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\data_reader.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\data_reader_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\decoding.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\devices.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\diet.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\diet_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\expert_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\expert_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\flags.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\get_cnndm_rouge.sh'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\get_ende_bleu.sh'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\get_rouge.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\hparam.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\hparams_lib.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\hparams_lib_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\hparam_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\learning_rate.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\metrics.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\metrics_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\metrics_hook_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\metrics_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\misc_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\misc_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\mlperf_log.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\mlperf_tags.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\mtf_model.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\multistep_optimizer.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\multistep_optimizer_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\optimize.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\optimize_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\partial_checkpoint_load_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\pruning_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\quantization.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\registry.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\registry_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\restore_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\rouge.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\rouge_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\sari_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\sari_hook_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\scheduled_sampling.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\t2t_model.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\t2t_model_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\test_utils.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\test_utils_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\trainer_lib.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\trainer_lib_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\update_ops_hook.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\usr_dir.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video2gif.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video_metrics.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video_metrics_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\yellowfin.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\yellowfin_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\__init__.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\utils\\video': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video\\prediction2gif.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\utils\\video\\reward_confusion.py'}],
#  'test\\tensor2tensor\\tensor2tensor\\visualization': [{'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\attention.js'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\attention.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\TransformerVisualization.ipynb'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\visualization.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\visualization_test.py'},
#   {'type': 'file',
#    'value': 'test\\tensor2tensor\\tensor2tensor\\visualization\\__init__.py'}]}
